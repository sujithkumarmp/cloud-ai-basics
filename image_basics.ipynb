# %% [markdown]
# <a href="https://colab.research.google.com/github/sujithkumarmp/cloud-ai-basics/blob/main/image_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pillow

# %%
from PIL import Image

# %%
pic = Image.open("sample_data/Grosser_Panda.JPG")

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x167>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import numpy as np
pic_arr=np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (167, 250, 3)

# %%
pic_arr
# Out:
# array([[[ 41,  65,  33],
#         [ 44,  68,  36],
#         [ 54,  78,  46],
#         ...,
#         [ 10,  35,  32],
#         [  7,  33,  34],
#         [ 19,  45,  46]],
#
#        [[ 50,  71,  40],
#         [ 49,  73,  41],
#         [ 60,  81,  50],
#         ...,
#         [  3,  27,  27],
#         [ 26,  52,  53],
#         [ 53,  81,  84]],
#
#        [[ 52,  71,  41],
#         [ 50,  71,  40],
#         [ 56,  75,  45],
#         ...,
#         [ 67,  92,  96],
#         [101, 129, 133],
#         [ 82, 111, 115]],
#
#        ...,
#
#        [[ 90,  98,  77],
#         [105, 113,  92],
#         [ 40,  43,  24],
#         ...,
#         [ 65,  59,  47],
#         [ 84,  80,  68],
#         [ 81,  77,  65]],
#
#        [[ 84,  92,  69],
#         [ 66,  71,  49],
#         [ 20,  23,   2],
#         ...,
#         [ 65,  59,  47],
#         [ 88,  84,  72],
#         [ 92,  88,  76]],
#
#        [[ 56,  64,  40],
#         [ 89,  94,  71],
#         [100, 104,  81],
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(pic_arr)

# %%
pic_red= pic_arr.copy()

# %%
pic_red[:,:,1]
# Out:
# array([[ 65,  68,  78, ...,  35,  33,  45],
#        [ 71,  73,  81, ...,  27,  52,  81],
#        [ 71,  71,  75, ...,  92, 129, 111],
#        ...,
#        [ 98, 113,  43, ...,  59,  80,  77],
#        [ 92,  71,  23, ...,  59,  84,  88],
#        [ 64,  94, 104, ...,  80,  56,  68]], dtype=uint8)

# %%
pic_red[:,:,1]=0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,2]=0

# %%
plt.imshow(pic_red)

# %%
pip install opencv-python

# %%
import cv2

# %%
img = cv2.imread("sample_data/Grosser_Panda.JPG")

# %%
plt.imshow(img)

# %%
img_gray = cv2.imread("sample_data/Grosser_Panda.JPG", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap="gray")
